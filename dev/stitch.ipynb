# %%
#!/home/ubuntu/.conda/envs/quixotic/bin/python

# %%
import pandas as pd
import os
import datetime
import pytz

import parameters

# %%
# TO DO: move DB parameters to file

import mysql.connector

DB_USER = parameters.DB_USER
DB_PASSWORD = parameters.DB_PASSWORD
DB_HOST = parameters.DB_HOST
DB_NAME = parameters.DB_NAME

# %%
DATA_DIR_RESCUE_TIME = parameters.DATA_DIR_RESCUE_TIME
DATA_DIR_EMAIL = parameters.DATA_DIR_EMAIL
DATA_DIR_CALENDAR = parameters.DATA_DIR_CALENDAR
ETL_DIR = parameters.ETL_DIR

USER_TIMEZONE = "US/Eastern"

# %%
df_rt = pd.DataFrame()
names = ['hour', 'duration', 'title', 'detail']

#file = 'zcarwile_2015-10-02.txt'
for file in os.listdir(DATA_DIR_RESCUE_TIME):
    df_tmp = pd.DataFrame()
    if ".txt" in file:
        full_path = '%s/%s' % (DATA_DIR_RESCUE_TIME, file)
        try:
            df_tmp = pd.read_table(full_path, sep='\t', header=None, names=names)
            df_rt = pd.concat([df_rt, df_tmp], ignore_index=True)
        except:
            print('Error processing: ' + full_path)
    
df_rt.tail()
# Out:
#                       hour  duration               title  \
# 21704  2017-01-06T18:00:00       248    play.spotify.com
# 21705  2017-01-07T12:00:00      1389              iterm2
# 21706  2017-01-07T12:00:00       241              python
# 21707  2017-01-07T12:00:00       100   stackoverflow.com
# 21708  2017-01-07T12:00:00        77  barrysbootcamp.com
#
#                                                   detail
# 21704                                         No Details
# 21705                                         No Details
# 21706                                Spyder (Python 2.7)
# 21707  load parameters from a file in Python - Stack ...
# 21708                                         No Details

# %%
# to make RT data "aware"
def to_aware(hour, timezone):
    est = pytz.timezone(timezone)
    aware = est.localize(datetime.datetime.strptime(hour,'%Y-%m-%dT%H:%M:%S'))
    return(aware)
                         
df_rt['start'] = df_rt.apply(lambda row: to_aware(row['hour'], USER_TIMEZONE), axis=1)
df_rt['start'] = pd.to_datetime(df_rt['start'], utc=True)

# %%
# create fake end time
# ultimately, rescue time is a poor data source because we're not using the raw tracks.  but ok for illustration
def create_end_time(hour, timezone, duration):
    est = pytz.timezone(timezone)
    tmp = est.localize(datetime.datetime.strptime(hour,'%Y-%m-%dT%H:%M:%S')) 
    duration = int(duration)
    end_time = tmp + datetime.timedelta(seconds=duration)
    return(end_time)

df_rt['end'] = df_rt.apply(lambda row: create_end_time(row['hour'], USER_TIMEZONE, row['duration']), axis=1)
df_rt['end'] = pd.to_datetime(df_rt['end'], utc=True)

df_rt.drop('hour', 1, inplace=True)
df_rt.drop('duration', 1, inplace=True)

# %%
df_rt.sort_values(by='start', inplace=True)
df_rt['tags'] = 'Rescue Time'

df_rt.tail()
# Out:
#                     title                                             detail  \
# 21704    play.spotify.com                                         No Details
# 21707   stackoverflow.com  load parameters from a file in Python - Stack ...
# 21705              iterm2                                         No Details
# 21706              python                                Spyder (Python 2.7)
# 21708  barrysbootcamp.com                                         No Details
#
#                     start                 end         tags
# 21704 2017-01-06 23:00:00 2017-01-06 23:04:08  Rescue Time
# 21707 2017-01-07 17:00:00 2017-01-07 17:01:40  Rescue Time
# 21705 2017-01-07 17:00:00 2017-01-07 17:23:09  Rescue Time
# 21706 2017-01-07 17:00:00 2017-01-07 17:04:01  Rescue Time
# 21708 2017-01-07 17:00:00 2017-01-07 17:01:17  Rescue Time

# %%
# Email
#file = 'zcarwile_1.txt'

df_email = pd.DataFrame()
names = ['detail','sent','features','title','redaction'] # TO DO: need an extra column -- for now I'm just stuffing

for file in os.listdir(DATA_DIR_EMAIL):
    if ".txt" in file:
        df_tmp = pd.DataFrame()
        full_path = '%s/%s' % (DATA_DIR_EMAIL, file)
        try:
            df_tmp = pd.read_table(full_path, header=None, names=names)
            df_email = pd.concat([df_email, df_tmp], ignore_index=True)
        except:
            print('Error processing: ' + full_path)
            
df_email['start'] = pd.to_datetime(df_email['sent'], utc=True)
df_email.drop('sent', 1, inplace=True)

df_email.sort_values(by='start', inplace=True)

df_email['tags'] = 'Gmail'
df_email.tail()
# Out:
#                detail                                  features  \
# 101  15975e7189105579                    ttolerico@continuum.io
# 100  15975e72dde2fe1b         Payal Cudia <pcudia@continuum.io>
# 104  15976090ca414696  Zach Carwile <Zachary.carwile@gmail.com>
# 103  1597666e7bd9d553                      jamaral@continuum.io
# 102  15979c8a97009308                    pcesarini@continuum.io
#
#                                                  title  \
# 101  Accepted: Founder Friday @ Fri Jan 27, 2017 11...
# 100            Re: Your AnacondaCON Hotel Confirmation
# 104                                            testing
# 103  Accepted: Continuum POC Call with Kaiser @ Tue...
# 102  Accepted: Continuum Analytics /Govinvest Servi...
#
#                                              redaction               start  \
# 101  Zachary Carwile has accepted this invitation. ... 2017-01-06 22:29:56
# 100  Thanks! _______________________________ Zachar... 2017-01-06 22:30:01
# 104  _______________________________ Zachary Carwil... 2017-01-06 23:07:01
# 103  Zachary Carwile has accepted this invitation. ... 2017-01-07 00:49:32
# 102  Zachary Carwile has accepted this invitation. ... 2017-01-07 16:35:10
#
#       tags
# 101  Gmail
# 100  Gmail
# 104  Gmail
# 103  Gmail
# 102  Gmail

# %%
# Calendar
#file = 'zcarwile_1.txt'
df_calendar = pd.DataFrame()
names = ['detail','start_time','end_time','features','title']

for file in os.listdir(DATA_DIR_CALENDAR):
    if ".txt" in file:
        full_path = '%s/%s' % (DATA_DIR_CALENDAR, file)
        try:
            df_tmp = pd.read_table(full_path, header=None, names=names)
            df_calendar = pd.concat([df_calendar, df_tmp], ignore_index=True)
        except:
            print('Error processing: ' + full_path)


df_calendar['start'] = pd.to_datetime(df_calendar['start_time'], utc=True)
df_calendar['end'] = pd.to_datetime(df_calendar['end_time'], utc=True)

df_calendar.drop('start_time', 1, inplace=True)
df_calendar.drop('end_time', 1, inplace=True)

df_calendar.sort_values(by='start', inplace=True)
df_calendar['tags'] = 'Google Calendar'

df_calendar.tail()
# Out:
#                                                 detail  \
# 180                         ngs1n79tsj3rimcv0l235nnkds
# 181                         r18vlg88m6g23lu5a3o8i87mk4
# 182                         23kcjej2iqe05ep3u37fnp5p9g
# 184  _60q30c1g60o30e1i60o4ac1g60rj8gpl88rj2c1h84s34...
# 183  _60q30c1g60o30e1i60o4ac1g60rj8gpl88rj2c1h84s34...
#
#                      features                              title  \
# 180                      None           Small Improvements draft
# 181                      None                              relax
# 182                      None                      Dinner w/Rudy
# 184  Felipe Castillo Carvajal         AEN - Security touch point
# 183                      None  Precall for Anaconda Installation
#
#                   start                 end             tags
# 180 2017-01-06 22:00:00 2017-01-06 23:00:00  Google Calendar
# 181 2017-01-06 23:30:00 2017-01-06 23:45:00  Google Calendar
# 182 2017-01-08 00:00:00 2017-01-08 03:00:00  Google Calendar
# 184 2017-01-09 14:00:00 2017-01-09 15:00:00  Google Calendar
# 183 2017-01-09 14:00:00 2017-01-09 16:00:00  Google Calendar

# %%
# Check for unified data types in timestamp
#print(type(df_rt.loc[0]['start']))
#print(type(df_rt.loc[0]['start']))
#print(type(df_email.loc[0]['start']))
#print(type(df_calendar.loc[0]['start']))
#print(type(df_calendar.loc[0]['end']))

# %%
frames = [df_rt, df_email, df_calendar]

result = pd.concat(frames, ignore_index=True)
result.sort_values(by='start', inplace=True)
result['user_id'] = 1
result.tail(100)
# Out:
#                                                   detail                 end  \
# 21649                                Spyder (Python 3.4) 2017-01-05 23:04:39
# 21642                                         No Details 2017-01-05 23:03:40
# 21643  Users.messages  |  Gmail API  |  Google Develo... 2017-01-05 23:01:29
# 21644  API Reference  |  Google Calendar API  |  Goog... 2017-01-05 23:01:45
# 21645  Events  |  Google Calendar API  |  Google Deve... 2017-01-05 23:03:10
# 21646                                         No Details 2017-01-05 23:03:52
# 21647  Gmail API Overview  |  Gmail API  |  Google De... 2017-01-05 23:04:57
# 21648                                         No Details 2017-01-05 23:07:05
# 21798                                   15970ed3c03ba251                 NaT
# 22806                         h2tqa340jqocgpjjsrf7rl365g 2017-01-06 02:00:00
# 21650                                         No Details 2017-01-06 14:06:39
# 21651                                         No Details 2017-01-06 14:01:36
# 21652                                         No Details 2017-01-06 14:01:28
# 21799                                   1597428d39b70b6e                 NaT
# 21800                                   15974435bf985bcd                 NaT
# 21656                                         No Details 2017-01-06 15:02:16
# 21657                                         No Details 2017-01-06 15:02:51
# 21658                                         No Details 2017-01-06 15:09:02
# 21659                                         No Details 2017-01-06 15:12:06
# 21660                                Spyder (Python 3.4) 2017-01-06 15:21:45
# 21661                                         No Details 2017-01-06 15:03:56
# 21654                                         No Details 2017-01-06 15:01:40
# 21655                                         No Details 2017-01-06 15:01:48
# 22807                         723i8otsgl30548s8n3pode03o 2017-01-06 15:15:00
# 21653                                         No Details 2017-01-06 15:01:37
# 21801                                   159744c3e9e78953                 NaT
# 22808                         2eanb7blgjvs8vqv74tnc8gg20 2017-01-06 16:30:00
# 21802                                   15974813d704fa22                 NaT
# 21673  python - how to get tz_info object correspondi... 2017-01-06 16:03:38
# 21662  How to add timezone into a naive datetime inst... 2017-01-06 16:01:04
# ...                                                  ...                 ...
# 22815                         t04ac6k5hsu6le2aba9dqheoo4 2017-01-06 21:00:00
# 21808                                   1597589527739b4c                 NaT
# 21694  Events: list  |  Google Calendar API  |  Googl... 2017-01-06 21:01:22
# 21693                                Spyder (Python 3.4) 2017-01-06 21:45:11
# 21697                                           calendar 2017-01-06 21:01:03
# 21695                                         No Details 2017-01-06 21:01:17
# 21696                                        rescue_time 2017-01-06 21:01:06
# 22817                         dk0pqomrgajuo5ut73joejg4g8 2017-01-06 21:45:00
# 22816                         dk0pqomrgajuo5ut73joejg4g8 2017-01-06 21:45:00
# 21701                                Spyder (Python 3.4) 2017-01-06 22:16:27
# 22818                         ngs1n79tsj3rimcv0l235nnkds 2017-01-06 23:00:00
# 21702  python - Parsing date with timezone from an em... 2017-01-06 22:01:57
# 21700                                         No Details 2017-01-06 22:19:33
# 21699  timezone - Python - get UTC offset by seconds ... 2017-01-06 22:01:20
# 21698  datetime - Is time.mktime timezone free in pyt... 2017-01-06 22:01:08
# 21809                                   15975e7189105579                 NaT
# 21810                                   15975e72dde2fe1b                 NaT
# 21703                                         No Details 2017-01-06 23:05:21
# 21704                                         No Details 2017-01-06 23:04:08
# 21811                                   15976090ca414696                 NaT
# 22819                         r18vlg88m6g23lu5a3o8i87mk4 2017-01-06 23:45:00
# 21812                                   1597666e7bd9d553                 NaT
# 21813                                   15979c8a97009308                 NaT
# 21708                                         No Details 2017-01-07 17:01:17
# 21705  load parameters from a file in Python - Stack ... 2017-01-07 17:01:40
# 21706                                         No Details 2017-01-07 17:23:09
# 21707                                Spyder (Python 2.7) 2017-01-07 17:04:01
# 22820                         23kcjej2iqe05ep3u37fnp5p9g 2017-01-08 03:00:00
# 22821  _60q30c1g60o30e1i60o4ac1g60rj8gpl88rj2c1h84s34... 2017-01-09 15:00:00
# 22822  _60q30c1g60o30e1i60o4ac1g60rj8gpl88rj2c1h84s34... 2017-01-09 16:00:00
#
#                                                 features  \
# 21649                                                NaN
# 21642                                                NaN
# 21643                                                NaN
# 21644                                                NaN
# 21645                                                NaN
# 21646                                                NaN
# 21647                                                NaN
# 21648                                                NaN
# 21798  Kristopher Overholt <koverholt@continuum.io>, ...
# 22806                                               None
# 21650                                                NaN
# 21651                                                NaN
# 21652                                                NaN
# 21799  Felipe Castillo Carvajal <Felipe.Castillo@equi...
# 21800                             pcesarini@continuum.io
# 21656                                                NaN
# 21657                                                NaN
# 21658                                                NaN
# 21659                                                NaN
# 21660                                                NaN
# 21661                                                NaN
# 21654                                                NaN
# 21655                                                NaN
# 22807                                               None
# 21653                                                NaN
# 21801  francisco.e.huante.ctr@mail.mil, shalindra.j.f...
# 22808                                        Atish Singh
# 21802           Zach Carwile <Zachary.carwile@gmail.com>
# 21673                                                NaN
# 21662                                                NaN
# ...                                                  ...
# 22815                                               None
# 21808                             ttolerico@continuum.io
# 21694                                                NaN
# 21693                                                NaN
# 21697                                                NaN
# 21695                                                NaN
# 21696                                                NaN
# 22817                                               None
# 22816                                               None
# 21701                                                NaN
# 22818                                               None
# 21702                                                NaN
# 21700                                                NaN
# 21699                                                NaN
# 21698                                                NaN
# 21809                             ttolerico@continuum.io
# 21810                  Payal Cudia <pcudia@continuum.io>
# 21703                                                NaN
# 21704                                                NaN
# 21811           Zach Carwile <Zachary.carwile@gmail.com>
# 22819                                               None
# 21812                               jamaral@continuum.io
# 21813                             pcesarini@continuum.io
# 21708                                                NaN
# 21705                                                NaN
# 21706                                                NaN
# 21707                                                NaN
# 22820                                               None
# 22821                           Felipe Castillo Carvajal
# 22822                                               None
#
#                                                redaction               start  \
# 21649                                                NaN 2017-01-05 23:00:00
# 21642                                                NaN 2017-01-05 23:00:00
# 21643                                                NaN 2017-01-05 23:00:00
# 21644                                                NaN 2017-01-05 23:00:00
# 21645                                                NaN 2017-01-05 23:00:00
# 21646                                                NaN 2017-01-05 23:00:00
# 21647                                                NaN 2017-01-05 23:00:00
# 21648                                                NaN 2017-01-05 23:00:00
# 21798  Hi Kris, Christine: Charles Schwab wants our n... 2017-01-05 23:18:32
# 22806                                                NaN 2017-01-05 23:30:00
# 21650                                                NaN 2017-01-06 14:00:00
# 21651                                                NaN 2017-01-06 14:00:00
# 21652                                                NaN 2017-01-06 14:00:00
# 21799  Yes, I will double check on this. Thanks, Zach... 2017-01-06 14:22:29
# 21800  Zachary Carwile has accepted this invitation. ... 2017-01-06 14:51:28
# 21656                                                NaN 2017-01-06 15:00:00
# 21657                                                NaN 2017-01-06 15:00:00
# 21658                                                NaN 2017-01-06 15:00:00
# 21659                                                NaN 2017-01-06 15:00:00
# 21660                                                NaN 2017-01-06 15:00:00
# 21661                                                NaN 2017-01-06 15:00:00
# 21654                                                NaN 2017-01-06 15:00:00
# 21655                                                NaN 2017-01-06 15:00:00
# 22807                                                NaN 2017-01-06 15:00:00
# 21653                                                NaN 2017-01-06 15:00:00
# 21801  Hi Shalindra, Francisco: I&#39;m reaching out ... 2017-01-06 15:01:11
# 22808                                                NaN 2017-01-06 15:30:00
# 21802  _______________________________ Zachary Carwil... 2017-01-06 15:59:04
# 21673                                                NaN 2017-01-06 16:00:00
# 21662                                                NaN 2017-01-06 16:00:00
# ...                                                  ...                 ...
# 22815                                                NaN 2017-01-06 20:00:00
# 21808  Zachary Carwile has accepted this invitation. ... 2017-01-06 20:47:31
# 21694                                                NaN 2017-01-06 21:00:00
# 21693                                                NaN 2017-01-06 21:00:00
# 21697                                                NaN 2017-01-06 21:00:00
# 21695                                                NaN 2017-01-06 21:00:00
# 21696                                                NaN 2017-01-06 21:00:00
# 22817                                                NaN 2017-01-06 21:30:00
# 22816                                                NaN 2017-01-06 21:30:00
# 21701                                                NaN 2017-01-06 22:00:00
# 22818                                                NaN 2017-01-06 22:00:00
# 21702                                                NaN 2017-01-06 22:00:00
# 21700                                                NaN 2017-01-06 22:00:00
# 21699                                                NaN 2017-01-06 22:00:00
# 21698                                                NaN 2017-01-06 22:00:00
# 21809  Zachary Carwile has accepted this invitation. ... 2017-01-06 22:29:56
# 21810  Thanks! _______________________________ Zachar... 2017-01-06 22:30:01
# 21703                                                NaN 2017-01-06 23:00:00
# 21704                                                NaN 2017-01-06 23:00:00
# 21811  _______________________________ Zachary Carwil... 2017-01-06 23:07:01
# 22819                                                NaN 2017-01-06 23:30:00
# 21812  Zachary Carwile has accepted this invitation. ... 2017-01-07 00:49:32
# 21813  Zachary Carwile has accepted this invitation. ... 2017-01-07 16:35:10
# 21708                                                NaN 2017-01-07 17:00:00
# 21705                                                NaN 2017-01-07 17:00:00
# 21706                                                NaN 2017-01-07 17:00:00
# 21707                                                NaN 2017-01-07 17:00:00
# 22820                                                NaN 2017-01-08 00:00:00
# 22821                                                NaN 2017-01-09 14:00:00
# 22822                                                NaN 2017-01-09 14:00:00
#
#                   tags                                              title  \
# 21649      Rescue Time                                             python
# 21642      Rescue Time                                       flowdock.com
# 21643      Rescue Time                              developers.google.com
# 21644      Rescue Time                              developers.google.com
# 21645      Rescue Time                              developers.google.com
# 21646      Rescue Time                                              Gmail
# 21647      Rescue Time                              developers.google.com
# 21648      Rescue Time                              ondemand.cloudera.com
# 21798            Gmail                                REST API deployment
# 22806  Google Calendar                                            FI guys
# 21650      Rescue Time                              thetruthaboutcars.com
# 21651      Rescue Time                                              Gmail
# 21652      Rescue Time                                       flowdock.com
# 21799            Gmail                       Re: Kerberos login UI update
# 21800            Gmail  Accepted: Continuum /Wells Fargo Bokeh Review ...
# 21656      Rescue Time                              ondemand.cloudera.com
# 21657      Rescue Time                                              Notes
# 21658      Rescue Time                                              Gmail
# 21659      Rescue Time                                             iterm2
# 21660      Rescue Time                                             python
# 21661      Rescue Time                                  screensaverengine
# 21654      Rescue Time                                nyc.streetsblog.org
# 21655      Rescue Time                                        dnainfo.com
# 22807  Google Calendar                                            NGC f/u
# 21653      Rescue Time                                         nypost.com
# 21801            Gmail                  Anaconda Workgroup implementation
# 22808  Google Calendar            Continuum/Luminus Technical discussion.
# 21802            Gmail                                               text
# 21673      Rescue Time                                  stackoverflow.com
# 21662      Rescue Time                                  stackoverflow.com
# ...                ...                                                ...
# 22815  Google Calendar               Continuum /Wells Fargo Bokeh Review
# 21808            Gmail  Accepted: All Hands 2017 KickOff Meeting @ Fri...
# 21694      Rescue Time                              developers.google.com
# 21693      Rescue Time                                             python
# 21697      Rescue Time                                             Finder
# 21695      Rescue Time                                    docs.python.org
# 21696      Rescue Time                                             Finder
# 22817  Google Calendar                              Equifax security prep
# 22816  Google Calendar                              Equifax security prep
# 21701      Rescue Time                                             python
# 22818  Google Calendar                           Small Improvements draft
# 21702      Rescue Time                                  stackoverflow.com
# 21700      Rescue Time                                             iterm2
# 21699      Rescue Time                                  stackoverflow.com
# 21698      Rescue Time                                  stackoverflow.com
# 21809            Gmail  Accepted: Founder Friday @ Fri Jan 27, 2017 11...
# 21810            Gmail            Re: Your AnacondaCON Hotel Confirmation
# 21703      Rescue Time                                             iterm2
# 21704      Rescue Time                                   play.spotify.com
# 21811            Gmail                                            testing
# 22819  Google Calendar                                              relax
# 21812            Gmail  Accepted: Continuum POC Call with Kaiser @ Tue...
# 21813            Gmail  Accepted: Continuum Analytics /Govinvest Servi...
# 21708      Rescue Time                                 barrysbootcamp.com
# 21705      Rescue Time                                  stackoverflow.com
# 21706      Rescue Time                                             iterm2
# 21707      Rescue Time                                             python
# 22820  Google Calendar                                      Dinner w/Rudy
# 22821  Google Calendar                         AEN - Security touch point
# 22822  Google Calendar                  Precall for Anaconda Installation
#
#        user_id
# 21649        1
# 21642        1
# 21643        1
# 21644        1
# 21645        1
# 21646        1
# 21647        1
# 21648        1
# 21798        1
# 22806        1
# 21650        1
# 21651        1
# 21652        1
# 21799        1
# 21800        1
# 21656        1
# 21657        1
# 21658        1
# 21659        1
# 21660        1
# 21661        1
# 21654        1
# 21655        1
# 22807        1
# 21653        1
# 21801        1
# 22808        1
# 21802        1
# 21673        1
# 21662        1
# ...        ...
# 22815        1
# 21808        1
# 21694        1
# 21693        1
# 21697        1
# 21695        1
# 21696        1
# 22817        1
# 22816        1
# 21701        1
# 22818        1
# 21702        1
# 21700        1
# 21699        1
# 21698        1
# 21809        1
# 21810        1
# 21703        1
# 21704        1
# 21811        1
# 22819        1
# 21812        1
# 21813        1
# 21708        1
# 21705        1
# 21706        1
# 21707        1
# 22820        1
# 22821        1
# 22822        1
#
# [100 rows x 8 columns]

# %%
# unified file with UTC timestamps

outfile = '%s/%s' % (ETL_DIR, 'zcarwile.txt')
result.to_csv(outfile, sep="\t")

# %%
# test for file pulled from EC2

#z = pd.read_csv('zcarwile.txt','\t')
#z.tail()

# %%
cnx = mysql.connector.connect(user=DB_USER, password=DB_PASSWORD, host=DB_HOST, db=DB_NAME)
result.to_sql('quixotic_api_event', cnx, flavor='mysql', if_exists='append', index=True, index_label='id')
cnx.close()
# Out:
# /Users/zcarwile/anaconda/envs/quixotic/lib/python3.4/site-packages/pandas/core/generic.py:1003: FutureWarning: The 'mysql' flavor with DBAPI connection is deprecated and will be removed in future versions. MySQL will be further supported with SQLAlchemy connectables.
#   dtype=dtype)

# %%
# HOW DO I initialize table in Django with a default user
#insert into quixotic_api_user (name) values ('zcarwile');
